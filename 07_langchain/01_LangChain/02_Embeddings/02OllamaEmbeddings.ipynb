# %% [markdown]
# ### OLLAMA EMBEDDINGS
# Ollama supports embeddings models, making it possible to build retrieval augmented generation (RAG) applications that combines text prompts with existing documents or other data

# %%
from langchain_community.embeddings import OllamaEmbeddings

embedding_model = (
    OllamaEmbeddings(model="gemma2:2b") ## by default it uses llama2 model, but to use any model you first have to install it in your local machine   
)
# Out:
# /var/folders/qs/xfx2840n0v52pb1c2p6x418m0000gn/T/ipykernel_77430/2284797889.py:4: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma2:2b") ## by default it uses llama2 model, but to use any model you first have to install it in your local machine

# %%
r1 = embedding_model.embed_documents(
    [
        "Alpha is the first character of Greek Alphabet",
        "Gamma is the second character of Greek Alphabet"
    ]
)

r1
# Out:
# [[0.6798059344291687,
#   -1.6548895835876465,
#   -2.223207473754883,
#   -0.07408233731985092,
#   0.4988327920436859,
#   1.0456879138946533,
#   1.6288621425628662,
#   -0.6486362814903259,
#   -0.08357132971286774,
#   1.1299006938934326,
#   -2.1491596698760986,
#   -1.1052906513214111,
#   -0.7135550379753113,
#   -0.9510860443115234,
#   -0.17451421916484833,
#   -0.275897353887558,
#   -5.070436477661133,
#   -1.1413551568984985,
#   -5.031309127807617,
#   -1.3664450645446777,
#   1.7604694366455078,
#   1.2273532152175903,
#   -2.3317787647247314,
#   -0.6140820384025574,
#   3.1757194995880127,
#   -0.8457452654838562,
#   0.9313580393791199,
#   0.9523131847381592,
#   -1.0029336214065552,
#   0.943689227104187,
#   -1.4286168813705444,
#   0.886751651763916,
#   -1.1759880781173706,
#   -1.6328513622283936,
#   -0.4383014738559723,
#   1.8213448524475098,
#   -1.4427862167358398,
#   1.2711901664733887,
#   0.8254117965698242,
#   -2.515812635421753,
# ...

# %%
r1[0]
# Out:
# [0.6798059344291687,
#  -1.6548895835876465,
#  -2.223207473754883,
#  -0.07408233731985092,
#  0.4988327920436859,
#  1.0456879138946533,
#  1.6288621425628662,
#  -0.6486362814903259,
#  -0.08357132971286774,
#  1.1299006938934326,
#  -2.1491596698760986,
#  -1.1052906513214111,
#  -0.7135550379753113,
#  -0.9510860443115234,
#  -0.17451421916484833,
#  -0.275897353887558,
#  -5.070436477661133,
#  -1.1413551568984985,
#  -5.031309127807617,
#  -1.3664450645446777,
#  1.7604694366455078,
#  1.2273532152175903,
#  -2.3317787647247314,
#  -0.6140820384025574,
#  3.1757194995880127,
#  -0.8457452654838562,
#  0.9313580393791199,
#  0.9523131847381592,
#  -1.0029336214065552,
#  0.943689227104187,
#  -1.4286168813705444,
#  0.886751651763916,
#  -1.1759880781173706,
#  -1.6328513622283936,
#  -0.4383014738559723,
#  1.8213448524475098,
#  -1.4427862167358398,
#  1.2711901664733887,
#  0.8254117965698242,
#  -2.515812635421753,
#  -0.5237579345703125,
#  1.5276968479156494,
# ...

# %%
len(r1[0])
# Out:
# 2304

# %%
r2 = embedding_model.embed_query("Gemma is third character of Greek Alphabet")
r2
# Out:
# [-0.2567797601222992,
#  -1.0303421020507812,
#  -2.460963726043701,
#  -0.44881200790405273,
#  0.8753013014793396,
#  0.5924981236457825,
#  1.2673914432525635,
#  0.10680857300758362,
#  -0.350633829832077,
#  2.055032253265381,
#  -3.218928813934326,
#  -0.36409878730773926,
#  -1.2519272565841675,
#  -0.6762681603431702,
#  0.3858983814716339,
#  -0.4576117992401123,
#  -3.5867748260498047,
#  -1.0190765857696533,
#  -5.9167094230651855,
#  -0.5259428024291992,
#  2.3588874340057373,
#  0.7517589330673218,
#  -2.40635085105896,
#  -0.9551827907562256,
#  3.0567188262939453,
#  -1.2817788124084473,
#  1.5962227582931519,
#  0.13145750761032104,
#  -0.5268984436988831,
#  1.4914249181747437,
#  -1.3349213600158691,
#  0.6488161087036133,
#  -1.8393480777740479,
#  -1.6749476194381714,
#  0.2845381796360016,
#  2.5963387489318848,
#  -2.2744195461273193,
#  0.2995375096797943,
#  0.8337571620941162,
#  -2.557943344116211,
#  0.17685937881469727,
#  2.9813106060028076,
# ...
